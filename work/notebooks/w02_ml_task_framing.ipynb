# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/MRazaRashid/FlyRank_Week1/blob/main/work/notebooks/w02_ml_task_framing.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %% [markdown]
# This is a ranking/scoring task. My goal is to produce a continuous score that orders all eligible pages from most to least worth a reviewer's limited attention. A reviewer works down a ranked list until their capacity runs out (e.g. top 50), so what matters is getting the order right at the top, not getting every page's label individually correct the way classification would.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %% [markdown]
# My proxy target is **is_declining_label**, defined as **trend_direction == "down"**.This comes from a defined rule, **trend_direction** is itself derived from **trend_pct** which is calculated from the current data window.I know this is a weaker "beginner proxy" for now, and a stronger version would use a real future-window outcome instead.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %% [markdown]
# My success metric is **precision@50**: of the top 50 pages my model ranks highest, how many are actually declining-with-demand pages? I'm choosing this over plain accuracy because this is a ranked-review problem — a reviewer only has capacity to check a limited number of pages, so what matters is whether the top of the list is trustworthy, not how the model performs across all 30,000 pages equally. The starter pipeline already gives me a number to beat: the rule-based baseline reaches 0.240 **precision@50** (about 12 of the top 50 are real hits), so any model I build needs to clear that bar to prove it's adding value.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import os, sys, subprocess, pandas as pd
IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

print("Working dir:", os.getcwd())
assert os.path.exists("data/raw/content_refresh_anonymized.csv"), "starter CSV not found — are you at the repo root?"
print("Starter data found.")

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
print("Shape : ",df.shape)
print("Unique count of content_id", df["content_id"].nunique())
assert df.shape[0] == df["content_id"].nunique(), "Grain check failed Duplicate rows per content item"
df[["content_id", "client_id", "impressions_90d", "trend_direction", "trend_pct"]].head()
# Out:
# Working dir: /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter/flyrank-ml-internship-starter
# Starter data found.
# Shape :  (30000, 44)
# Unique count of content_id 30000
#              content_id          client_id  impressions_90d trend_direction  \
# 0  content_304f48230142  client_f369cb89fc             3803            down
# 1  content_a1fb4e703a9e  client_4e07408562            15320            down
# 2  content_9aa793d4d895  client_7f2253d7e2            12581            down
# 3  content_331d6c4de07b  client_19581e27de            11751          stable
# 4  content_d99b7a2d90ca  client_3fdba35f04            19140            down
#
#    trend_pct
# 0      -41.4
# 1      -57.7
# 2      -60.9
# 3      -13.8
# 4      -34.7

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
